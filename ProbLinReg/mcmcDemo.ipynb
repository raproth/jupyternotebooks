# %%
import numpy as np
import pymc3 as pm
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# observed data
np.random.seed(123)
n = 110
_a = 0.5
_b = 0.1
x = np.linspace(0, 1, n)
y = _a*x + _b + np.random.randn(n)*0.05

# %%
niter = 500
with pm.Model() as linreg:
    a = pm.Normal('a', mu=_a, sigma=20)
    b = pm.Normal('b', mu=_b, sigma=20)
    sigma = pm.HalfCauchy('sigma',beta=10, testval=1.0)

    y_est = a*x + b
    likelihood = pm.Normal('y', mu=y_est, sigma=sigma, observed=y)

    start = pm.find_MAP()
    step = pm.NUTS(scaling=start)
    #trace = pm.sample(niter, step, start, random_seed=123)
    trace = pm.sample(niter)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# C:\Users\U230261\AppData\Local\Temp\ipykernel_18140\280693582.py:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(niter)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, b, a]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# Sampling 4 chains for 1_000 tune and 500 draw iterations (4_000 + 2_000 draws total) took 59 seconds.
# Could not locate executable g77
# Could not locate executable f77
# Could not locate executable ifort
# Could not locate executable ifl
# Could not locate executable f90
# Could not locate executable efl
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# The acceptance probability does not match the target. It is 0.8891449220769534, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
az.plot_posterior(trace)
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# C:\devsbb\Anaconda3\envs\pymc_env\lib\site-packages\arviz\data\io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# array([<AxesSubplot:title={'center':'a'}>,
#        <AxesSubplot:title={'center':'b'}>,
#        <AxesSubplot:title={'center':'sigma'}>], dtype=object)

# %%
plt.scatter(x, y, s=30, label='data',zorder=2)
for a_, b_ in zip(trace['a'][-200:], trace['b'][-200:]):
    plt.plot(x, a_*x + b_, c='gray', alpha=0.1,zorder=1)
plt.plot(x, _a*x + _b, label='true regression line', lw=3., c='red')
plt.legend(loc='best')
pass

# %%
sns.displot(trace['a'])

# %%
sns.displot(trace['b'])

# %%
tlim0 = np.zeros(trace['a'].size)

# %%
for (i,(a,b)) in enumerate(zip(trace['a'], trace['b'])):
    tlim0[i] = (1.0 - b)/a

# %%
xstart,median,xend = np.percentile(tlim0, [1,50,95])

# %%
median
# Out:
# 1.8538854013967647

# %%
sns.displot(tlim0, kde=False,rug=False,stat = "density")
plt.xlim(xstart,xend)
plt.show()

# %%
percentiles = [5, 25, 50, 75, 95]

# %%
ax = sns.histplot(tlim0, binwidth=0.01)
for (p,q) in zip(percentiles, np.percentile(tlim0, percentiles)):
    plt.xlim(xstart,xend)
    plt.axvline(q, color='orange')
    print(str(p)+"ntile=\t"+str(q))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 ax = sns.histplot(tlim0, binwidth=0.01)
#       2 for (p,q) in zip(percentiles, np.percentile(tlim0, percentiles)):
#       3     plt.xlim(xstart,xend)
#
# NameError: name 'tlim0' is not defined

# %%
# wahrer Wert
(1.0 - _b)/_a
# Out:
# 1.8
